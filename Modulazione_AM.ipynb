# %% [markdown]
# <a href="https://colab.research.google.com/github/davidedifilippo/jupyter_notebooks/blob/main/Modulazione_AM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt


#Portante 

Ap = 10
fp = 10

Tp = 1/fp

t = np.linspace(0, 2, num=1000000)

sp = Ap * np.cos(2*np.pi * fp * t)

plt.title('Signal')
plt.plot(t, sp, 'b')
plt.xlabel('Time [s]')
plt.ylabel('Voltage [V]')
plt.grid()
plt.show()

# %%
#Modulante

Am = 12
fm = 1

sm = Am * np.cos(2*np.pi * fm * t)

plt.title('Signal')
plt.plot(t, sm, 'b')
plt.xlabel('Time [s]')
plt.ylabel('Voltage [V]')
plt.grid()
plt.show()

# %%
#Modulato

k=1

smodulato = (Ap+k*sm)* np.cos(2*np.pi * fp * t)

#Andamento nel tempo

plt.title('Signal')
plt.plot(t, smodulato, 'b')
plt.xlabel('Time [s]')
plt.ylabel('Voltage [V]')
plt.grid()
plt.show()

# %%
#Modulato

k=1

#componenti in frequenza

smodulato = sp + (Am/2) * np.cos(2*np.pi * (fp+fm) * t) + (Am/2) * np.cos(2*np.pi * (fp-fm) * t)

plt.title('Signal')
plt.plot(t, smodulato, 'b')
plt.xlabel('Time [s]')
plt.ylabel('Voltage [V]')
plt.grid()
plt.show()
